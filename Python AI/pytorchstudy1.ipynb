# %%
import torch
import numpy as np

# %%
x = torch.empty(2, 2)
x
# Out:
# tensor([[1.0788e-34, 0.0000e+00],
#         [5.0447e-44, 0.0000e+00]])

# %%
x = torch.rand(2, 2)
x
# Out:
# tensor([[0.2072, 0.5113],
#         [0.0272, 0.6227]])

# %%
y = torch.rand(2, 2)
y
# Out:
# tensor([[0.5472, 0.0864],
#         [0.6335, 0.6671]])

# %%
z = torch.sub(x, y)
z
# Out:
# tensor([[-0.3400,  0.4249],
#         [-0.6063, -0.0444]])

# %%
x[1, 1].item()
# Out:
# 0.6226696372032166

# %%
a = torch.ones(2, 2)
b = a.numpy
a, b
# Out:
# (tensor([[1., 1.],
#          [1., 1.]]), <function Tensor.numpy>)

# %%
a.add_(1)
a, b
# Out:
# (tensor([[2., 2.],
#          [2., 2.]]), <function Tensor.numpy>)

# %%
a = np.ones(5)
b = torch.from_numpy(a)
a, b
# Out:
# (array([1., 1., 1., 1., 1.]),
#  tensor([1., 1., 1., 1., 1.], dtype=torch.float64))

# %%
if torch.cuda.is_available():
  device = torch.device("cuda")
  x = torch.ones(5, device=device)
  y = torch.ones(5)
  y = y.to(device)
  z = x + y
  z = z.to("cpu") # gpu tensor is not avalable to convert to numpy
  z.numpy()

# %%
x = torch.ones(5, requires_grad=True)
x
# Out:
# tensor([1., 1., 1., 1., 1.], requires_grad=True)

# %%
x = torch.randn(3)
y = torch.randn(3, requires_grad=True)
x, y
# Out:
# (tensor([ 0.1002,  1.5288, -0.1804]),
#  tensor([0.8973, 1.3415, 0.3568], requires_grad=True))

# %%
x = torch.ones(3, requires_grad=True)
print(x)

y = x + 2
print(y)

z = y * y * 2
print(z)
z = z.mean()
print(z)

z.backward()
print(x.grad)
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([3., 3., 3.], grad_fn=<AddBackward0>)
# tensor([18., 18., 18.], grad_fn=<MulBackward0>)
# tensor(18., grad_fn=<MeanBackward0>)
# tensor([4., 4., 4.])
